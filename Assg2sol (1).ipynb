# %%
Problem Set1:Variables,Data Types and I/O

# %%
product_price = 49.99
The data type of this variable is float.

# %%
is_active_user=True
The data type of this variable is boolean.

# %%
message="Hello ,World!"
print(message)

# %%
score=100
score=120
print(score)

# %%
a,b,c=10,20,30

# %%
The purpose is to return unique identity of an object.
x = 10
y = 10
z = [10]

print(id(x)) 
print(id(y)) 
print(id(z))

# %%
print(type("500"))   # string
print(type(500))     # integer

# %%
print("Python is fun!")

# %%
print("Hello", "Python", "World", sep="-")

# %%
print("This is the first sentence.", end=" ")
print("This is the second sentence.")

# %%
num_str = "123"       
num_int = int(num_str) 
print(num_int)
print(type(num_int))
# Out:
# 123
# <class 'int'>

# %%
num_int = 99          
num_float = float(num_int) 
print(num_float)
print(type(num_float))

# %%
num_int = 1000
num_float = 3.14

str_int = str(num_int)     
str_float = str(num_float) 

print(str_int, type(str_int))
print(str_float, type(str_float))

# %%
temperature = float(input("Enter the temperature: "))

if temperature > 30:
    print("It's hot outside.")
else:
    print("The weather is nice.")

# %%
grade = 85  
if grade >= 90:
    print("A")
elif grade >= 80:
    print("B")
elif grade >= 70:
    print("C")
elif grade >= 60:
    print("D")
else:
    print("F")

# %%
number = int(input("Enter an integer: "))

if number % 2 == 0:
    print("Even.")
else:
    print("Odd.")

# %%
x = 10
y = 20

if x < y and x > 5:
    print("Condition met.")

# %%
password = input("Enter your password: ")

if len(password) >= 8:
    print("Password is valid.")
else:
    print("Password is too short.")

# %%
fruits = ['apple', 'banana', 'cherry']

for fruit in fruits:
    print(fruit)

# %%
for num in range(1, 11): 
    print(num)

# %%
numbers = [1, 2, 3, 4, 5]
total = 0

for num in numbers:
    total += num

print("Sum:", total)

# %%
num = 10

while num >= 1:
    print(num)
    num -= 1

# %%
num = int(input("Enter a number (0 to stop): "))

while num != 0:
    print("You entered:", num)
    num = int(input("Enter a number (0 to stop): "))

print("Loop ended. You entered 0.")

# %%
for char in "Python":
    print(char)
